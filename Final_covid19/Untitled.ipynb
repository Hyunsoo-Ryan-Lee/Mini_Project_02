# %%
from selenium import webdriver 
from bs4 import BeautifulSoup 
import time
import pandas as pd
import numpy as np
import requests
import pyautogui
import os

# %%
world_vac = pd.read_csv("C:/Users/Playdata/Downloads/vaccinations.csv")
world_vac
# Out:
#           location iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 33901     Zimbabwe      ZWE  2021-07-11           1491397.0
# 33902     Zimbabwe      ZWE  2021-07-12           1531868.0
# 33903     Zimbabwe      ZWE  2021-07-13           1575539.0
# 33904     Zimbabwe      ZWE  2021-07-14           1613640.0
# 33905     Zimbabwe      ZWE  2021-07-15           1666862.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...
